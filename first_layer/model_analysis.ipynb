# %%
import torchvision.models as models
import torch
import numpy as np

BATCH_SIZE = 1

# Input image dimensions
input_height, input_width, input_channels = 227, 227, 3
sample_input = torch.tensor(np.random.randn(BATCH_SIZE, 3, 227, 227), dtype=torch.float32)

# model = models.wide_resnet101_2(pretrained=False)
model = models.resnext101_32x8d(pretrained=False)
# model = models.vgg19_bn(pretrained=False)

print(sample_input.shape)
print(model)
model_result = model(sample_input)
# Out:
# /home/hwlee/anaconda3/envs/hw39/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/hwlee/anaconda3/envs/hw39/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# torch.Size([1, 3, 227, 227])
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
# ...

# %%
import torch
last_model = torch.nn.Sequential(*list(model.children())[4:])
print(last_model)
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
import torch
from torchvision import models

model = torch.load("./best_model.pth")
print(model)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/hwlee/senier/first_layer/model_analysis.ipynb Cell 3 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2253656e696572227d/home/hwlee/senier/first_layer/model_analysis.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import torch
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2253656e696572227d/home/hwlee/senier/first_layer/model_analysis.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from torchvision import models
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2253656e696572227d/home/hwlee/senier/first_layer/model_analysis.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> model = torch.load("./best_model.pth")
# ...

# %%
import torch
from torchvision import models

model = models.resnext101_32x8d(pretrained=False)


# 특정 레이어의 출력 형태 확인
layer_number = 5  # 예시로 5번째 레이어를 선택
x = torch.randn(1, 3, 224, 224)  # 모델에 넣을 적절한 크기의 입력
for idx, layer in enumerate(model.children()):
    x = layer(x)
    if idx == layer_number:
        print(x.shape)  # 선택한 레이어의 출력 형태 출력
# Out:
# torch.Size([1, 512, 28, 28])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/hwlee/senier/first_layer/model_analysis.ipynb Cell 4 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2253656e696572227d/home/hwlee/senier/first_layer/model_analysis.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> x = torch.randn(1, 3, 224, 224)  # 모델에 넣을 적절한 크기의 입력
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2253656e696572227d/home/hwlee/senier/first_layer/model_analysis.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> for idx, layer in enumerate(model.children()):
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2253656e696572227d/home/hwlee/senier/first_layer/model_analysis.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     x = layer(x)
# ...
